# %%
import pandas as pd

# %%
temp_max_df = pd.read_csv('./sort_by_tempmax.csv')
temp_max_df.head()
# Out:
#    Unnamed: 0  datetime     name  tempmax  tempmin  temp  feelslikemax  \
# 0         513      2014  Beijing     42.0     19.8  30.4          39.0
# 1        3838      2023  Beijing     42.0     19.0  31.6          40.6
# 2        3824      2023  Beijing     41.0     20.0  32.3          39.2
# 3        3833      2023  Beijing     41.0     24.0  33.0          40.1
# 4        2005      2018  Beijing     40.2     20.0  30.0          38.5
#
#    feelslikemin  feelslike   dew  ...  solarenergy  uvindex  severerisk  \
# 0          19.8       29.3  10.1  ...         29.2       10         NaN
# 1          19.0       30.9  54.9  ...         27.0       10        10.0
# 2          20.0       31.3  53.4  ...         30.1       10        10.0
# 3          24.0       32.7  58.6  ...         26.2        9        10.0
# 4          20.0       29.1  12.5  ...         27.6        9         NaN
#
#                sunrise               sunset  moonphase  \
# ...
